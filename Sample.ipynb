# %%
import pandas as pd 
import seaborn as sns
import numpy as np 

import matplotlib.pyplot as plt 
import math 

import sklearn

# %%
df = pd.read_csv('Blood_samples_dataset_balanced_2(f).csv')

print(df.head(5))
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

f = pd.read_csv('Blood_samples_dataset_balanced_2(f).csv')

# Extract columns for Glucose and Hemoglobin
glucose = f.iloc[:, 0]  # First column for Glucose
hemoglobin = f.iloc[:, 2]  # Third column for Hemoglobin

# Scatter plot for Glucose vs Hemoglobin
plt.figure(figsize=(8, 6))
plt.scatter(glucose, hemoglobin, color='blue', alpha=0.6)
plt.title('Glucose vs Hemoglobin')
plt.xlabel('Glucose')
plt.ylabel('Hemoglobin')
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# ...

# %%
sns.barplot(df, y = "Red Blood Cells", x= "Disease")
# Out:
# <Axes: xlabel='Disease', ylabel='Red Blood Cells'>
